# %% [markdown]
# # 셀레니움 패키지 설치

# %%
# 라이브러리 설치 여부 확인
# ! pip list 

# 라이브러리 설치
# ! pip install 패키지명
# ! pip install selenium
# ! pip install webdriver-manager

# %% [markdown]
# # webdriver 실행하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


# 사전 설치된 webdriver 프로그램 구동 방식
# s = Service('c:/DEV/chromedriver_win32/chromedriver.exe')
# # 임의로 만든 DEV 폴더에 크롬 드라이버 exe 파일이 다운로드 되어져 있는 경우를 가정 (브라우저별 웹 드라이버 exe 파일을 다운로드 해야함)
# driver = webdriver.Chrome(service=s)


# webdriver 동적 다운로드 방식
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
# service라는 매개변수에 Service라는 class 객체를 생성하여 넣어주고, options라는 매개변수에는~

driver.get('https://news.naver.com')

# %% [markdown]
# # find_elements() 함수

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# 웹 드라이버 동적 다운로드 방식
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())

driver.get('https://www.naver.com')

el = driver.find_element(by=By.ID, value='themecast')
# id 속성의 값이 themecast인 것은 unique한 단 하나
print(type(el)) # <class 'selenium.webdriver.remote.webelement.WebElement'>
print(el.text)
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# 주제별 캐스트
# 오늘 읽을만한 글주제별로 분류된 다양한 글 모음
# 653 개의 글 관심주제 설정
# 이전
# 다음
# 엔터
# 스포츠
# 자동차
# 웹툰
# 경제
# 추천구독
# 레시피
# 리빙
# 재생
# 재생시간
# 00:42
# 숏폼
# '미래의 모습?' 로봇들의 축구경기 #ShortForm
# 스포츠 진기명기:인버리
# 재생
# 재생시간
# 00:59
# 숏폼
# 억울한 르브론? 또 나온 NBA 역대급 오심
# 마스터욱
# 스포츠 홈
# 야구
# 해외야구
# 축구
# 해외축구
# 농구
# 배구
# 골프
# 일반
# e스포츠
# 재생
# 재생시간
# 01:26
# 아찔한 순간
# '부상 조심' 안면 블로킹 후 고통을 호소하는 김지한
# 54분 전
# 프로배구 네이버스포츠
# 재생
# 재생시간
# 01:20
# 주요장면
# '그야말로 철벽' 혼자서 5개째 블로킹을 잡아내고 있는 배유나
# 1시간 전
# 프로배구 네이버스포츠
# 재생
# 재생시간
# 05:15
# 하이라이트
# [H/L] '1세트 대역전극' 한국도로공사, KGC 잡아내며 3위 굳히기
# 57분 전
# 프로배구 네이버스포츠
# 재생
# 재생시간
# 10:50
# 핫클립
# 터너는 떠났다...다저스의 새로운 3루수는 누구?
# 9시간 전
# 김형준의 야구야구
# 재생
# 재생시간
# 00:40
# 구단특집
# [그때 그 순간] 이병근 1997 K리그 12R
# 3시간 전
# 수원삼성블루윙즈
# 재생
# 재생시간
# 15:24
# 핫클립
# [2022 KBO 리그 회고록] 최종화. 한국시리즈
# 3시간 전
# KBO.OFFICIAL
# 재생
# 재생시간
# 04:55
# 주요장면
# ‘도대체 ‘몇 명을 제친 거야?’ 1500만 뷰의 주인공!
# 4시간 전
# 엠스플 뉴스팩토리
# 재생
# 재생시간
# 11:30
# 인터뷰
# '인천의 살아있는 전설' 김도혁, 역대급 인터뷰 나왔습니다
# ...

# %% [markdown]
# # 이벤트 제어하기

# %% [markdown]
# ## click()

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
# find element를 활용하기 위한 by 클래스

# 웹 드라이버 동적 다운로드 방식
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options = webdriver.ChromeOptions())

driver.get('https://www.naver.com')

element = driver.find_element(by=By.CLASS_NAME, value='link_media')
element.click()

# a태그의 class 속성의 값이 link_media인 것
# <a class="link_media" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y" data-clk="newsflash">연합뉴스</a>

# %% [markdown]
# ## send_keys()

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys # 특수키 사용

# 웹 드라이버 동적 다운로드 방식
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())

driver.get('https://www.naver.com')

element = driver.find_element(by=By.ID, value='query')
element.send_keys('python')

element.send_keys(Keys.ENTER)

# 문자열을 입력할 수 있는 필드를 생성하는 input 태그
# query라는 id는 unique
# <input id="query" name="query" type="text" title="검색어 입력" maxlength="255" class="input_text" tabindex="1" accesskey="s" style="ime-mode:active;" autocomplete="off" placeholder="검색어를 입력해 주세요." onclick="document.getElementById('fbm').value=1;" value="" data-atcmp-element="">

# %% [markdown]
# # Selenium과 BeautifulSoup 연결하기
# - Selenium으로 웹 구동 및 접근하여 html 페이지 얻어온 후에
# - BeautifulSoup으로 스크랩핑 하기

# %%
# 다음에서 데이터 분석 검색 후, 검색 결과 페이지에서 텍스트 정보 출력하기

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.daum.net')
element = driver.find_element(by=By.ID, value='q')
element.send_keys('데이터 분석')
element.send_keys(Keys.ENTER)

bs = BeautifulSoup(driver.page_source, 'html.parser')
# response.text가 아닌 driver.page_source에서 읽어온다
# print(bs)


# <input data-tiara-layer="header search searchbox" type="text" id="q" name="q" class="tf_keyword" title="검색어 입력" autocomplete="off" spellcheck="false" autocorrect="off" autocapitalize="off" size="55" tabindex="1" style="ime-mode:active;" data-tiara-action-name="header-search-searchbox" data-bind="value: keywordInput.searchQuery, hasFocus: keywordInput.isSelected, event: { keydown: onKeyDown, keyup: onKeyUp, focus: onFocus, blur: onBlur }">

# %% [markdown]
# # [실습] 네이버 로그인하기

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.naver.com')
element = driver.find_element(by=By.CLASS_NAME, value='link_login')
element.click()


# 로봇에 의해 클릭될 수 없게 막아둔 것.
time.sleep(1)

my_id = 'jamie9'
my_pw = 'seonjae1997'
element = driver.find_element(by=By.ID, value='id')
element.send_keys(my_id)
element = driver.find_element(by=By.ID, value='pw')
element.send_keys(my_pw)

# 로그인 버튼 클릭
element = driver.find_element(by=By.CLASS_NAME, value='btn_login')
element.click()


# <a href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com" class="link_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">네이버</span></i>로그인</a>

# <input type="text" id="id" name="id" placeholder="아이디" title="아이디" class="input_text" maxlength="41" value="">

# <input type="password" id="pw" name="pw" placeholder="비밀번호" title="비밀번호" class="input_text" maxlength="16">

# <button type="submit" class="btn_login" id="log.login"> <span class="btn_text">로그인</span> </button>

# %% [markdown]
# ## execute_script()

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.naver.com')
element = driver.find_element(by=By.CLASS_NAME, value='link_login')
element.click()


# 로봇에 의해 클릭될 수 없게 막아뒀으므로, 스크립트로 처리하여 로그인 해야함.
time.sleep(1)

my_id = 'jamie9'
my_pw = 'seonjae1997'

# Selenium을 통해서 자바스크립트를 실행하고자 할 때 사용하는 함수
driver.execute_script("document.getElementById('id').value = '"+my_id+"'")
# document : DOM 객체가 할당되어 있는 것이 document
# getElementByID : ID를 기준으로 한 element을 받아오는 것
# 결과 : input 태그가 넘어온다
# 해당 필드에 '싱글쿼트로 묶여있는 value 값'을 넣는다.
driver.execute_script("document.getElementById('pw').value = '"+my_pw+"'")


# 로그인 버튼 클릭
element = driver.find_element(by=By.CLASS_NAME, value='btn_login')
element.click()

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.naver.com')
element = driver.find_element(by=By.CLASS_NAME, value='link_login')
element.click()


# 로봇에 의해 클릭될 수 없게 막아뒀으므로, 스크립트로 처리하여 로그인 해야함.
time.sleep(1)

my_id = 'jamie9'
my_pw = 'seonjae1997'

# Selenium을 통해서 자바스크립트를 실행하고자 할 때 사용하는 함수
driver.execute_script("document.getElementById('id').value = '"+my_id+"'")
# document : DOM 객체가 할당되어 있는 것이 document
# getElementByID : ID를 기준으로 한 element을 받아오는 것
# 결과 : input 태그가 넘어온다
# 해당 필드에 '싱글쿼트로 묶여있는 value 값'을 넣는다.
driver.execute_script("document.getElementById('pw').value = '"+my_pw+"'")


# 로그인 상태 유지 체크박스 클릭
driver.execute_script("document.getElementById('keep').value = 'on'")


# 로그인 버튼 클릭
element = driver.find_element(by=By.CLASS_NAME, value='btn_login')
element.click()

# <input type="checkbox" id="keep" name="nvlong" class="input_keep" value="on">

# %%
# A.
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.naver.com')
element = driver.find_element(by=By.CLASS_NAME, value='link_login')
element.click()

time.sleep(1)
my_id = 'jamie9'
my_pw = 'seonjae1997'

driver.execute_script("document.getElementById('id'). value='" +my_id+ "'")
driver.execute_script("document.getElementById('pw'). value='" +my_pw+ "'")
driver.execute_script("document.getElementById('keep'). value='on'")

driver.find_element(by=By.ID, value="log.login").click()

# %% [markdown]
# # 웹 브라우저 자동 스크롤

# %% [markdown]
# ## [실습] 구글 이미지 검색하기

# %% [markdown]
# ### 검색 결과 6번 스크롤 하기

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# 대문자로 정의한 것은 '상수' (변수는 변하는 값, 상수는 변하지 않는 값)
SCROLL_PAUSE_TIME = 1 # 페이지가 로드될 때까지 기다리는 시간
SEARCH_KEYWORD = 'python'

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.google.co.kr')
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEYWORD)
element.submit()
# sumbit 함수 : html의 form 태그의 값을 서버로 전송할 때 호출하는 함수
# 웹 브라우저에서 정보를 입력하는 모든 태그 form tag라고 하는데, form tag의 값을 서버로 전달할 때 submit 함수를 사용한다.

# <input class="gLFyf" jsaction="paste:puy29d;" maxlength="2048" name="q" type="text" aria-autocomplete="both" aria-haspopup="false" autocapitalize="off" autocomplete="off" autocorrect="off" autofocus="" role="combobox" spellcheck="false" title="검색" value="" aria-label="검색" data-ved="0ahUKEwjt94P24_D8AhVulFYBHSTUAaIQ39UDCAY">

driver.find_element(by=By.LINK_TEXT, value='이미지').click()
time.sleep(SCROLL_PAUSE_TIME) # 페이지가 로그될 때까지 기다림
# <a href="/search?q=python&amp;sxsrf=AJOqlzUuzHC0YTAMtXJ-TjQvoJ6ALz4DhQ:1675132486241&amp;source=lnms&amp;tbm=isch&amp;sa=X&amp;ved=2ahUKEwj47Kzm4vD8AhXGF4gKHc9DDoAQ_AUoAXoECAEQAw&amp;cshid=1675132512181205&amp;biw=982&amp;bih=714&amp;dpr=1.25" data-hveid="CAEQAw"><span class="bmaJhd iJddsb" style="height:16px;width:16px"><svg focusable="false" viewBox="0 0 24 24"><path d="M14 13l4 5H6l4-4 1.79 1.78L14 13zm-6.01-2.99A2 2 0 0 0 8 6a2 2 0 0 0-.01 4.01zM22 5v14a3 3 0 0 1-3 2.99H5c-1.64 0-3-1.36-3-3V5c0-1.64 1.36-3 3-3h14c1.65 0 3 1.36 3 3zm-2.01 0a1 1 0 0 0-1-1H5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h7v-.01h7a1 1 0 0 0 1-1V5"></path></svg></span>이미지</a>


# 스크롤 내리기
last_height = driver.execute_script('return document.body.scrollHeight')
# 스크롤바 높이의 마지막 위치 값
for i in range(6):
    print('last_height: ', last_height)
    # 윈도우 창을 0에서부터 가장 밑(scrollHeight까지 이동)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.body.scrollHeight')
    print('new_height: ', new_height)
    print('-'*30)


### 더 이상 스크롤 될 페이지가 없을 경우 scrollHeight 값의 변화가 없다.
# Out:
# last_height:  3994
# new_height:  7875
# ------------------------------
# last_height:  3994
# new_height:  15873
# ------------------------------
# last_height:  3994
# new_height:  23387
# ------------------------------
# last_height:  3994
# new_height:  31143
# ------------------------------
# last_height:  3994
# new_height:  31224
# ------------------------------
# last_height:  3994
# new_height:  31224
# ------------------------------

# %% [markdown]
# ### 검색 결과 무한 스크롤 하기

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# 대문자로 정의한 것은 '상수' (변수는 변하는 값, 상수는 변하지 않는 값)
SCROLL_PAUSE_TIME = 1 # 페이지가 로드될 때까지 기다리는 시간
SEARCH_KEYWORD = 'python'

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.google.co.kr')
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEYWORD)
element.submit()


driver.find_element(by=By.LINK_TEXT, value='이미지').click()
time.sleep(SCROLL_PAUSE_TIME) # 페이지가 로그될 때까지 기다림



# 결과값 더보기
last_height = driver.execute_script('return document.body.scrollHeight')

# 스크롤 횟수
scroll_cnt = 1

while True :
    # 윈도우 창을 0에서부터 가장 밑(scrollHeight까지 이동)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.body.scrollHeight')
    print(f'last_height: {last_height}, new_height: {new_height}, scroll_count: {scroll_cnt}')
    
    if last_height != new_height : # 계속해서 new_height 값이 변경된다면..
        last_height = new_height # 스크롤 후의 new_height를 last_height에 넣기
        scroll_cnt += 1
    else: # 더 이상 new_height 값의 변동이 없다면..
        ### 해당 엘리먼트와 상호작용이 불가한 상태가 되면, ElementNotInteractableException 에외가 발생한다.
        element = driver.find_element(by=By.CSS_SELECTOR,value='#islmp > div > div > div > div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
        # ' > > > > ' : BeautifulSoup의 select()함수나 select_one()함수에서도 쓸 수 있으나, find()함수나 find_all()함수에서는 사용할 수 없다.
        element.click()
        print('결과 더보기 클릭')
        

# F12에서 Copy Selector 누르기 : #islmp > div > div > div > div > div.gBPM8 > div.qvfT1 > div.YstHxe > input
# Out:
# last_height: 3994, new_height: 7633, scroll_count: 1
# last_height: 7633, new_height: 15631, scroll_count: 2
# last_height: 15631, new_height: 23629, scroll_count: 3
# last_height: 23629, new_height: 30901, scroll_count: 4
# last_height: 30901, new_height: 30982, scroll_count: 5
# last_height: 30982, new_height: 30982, scroll_count: 6
# 결과 더보기 클릭
# last_height: 30982, new_height: 38168, scroll_count: 6
# last_height: 38168, new_height: 41159, scroll_count: 7
# last_height: 41159, new_height: 41159, scroll_count: 8
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13596\1218211426.py in <module>
#      43         element = driver.find_element(by=By.CSS_SELECTOR, value='#islmp > div > div > div > div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
# ...

# %% [markdown]
# ### 예외 처리 ElementNotInteractableException

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# 대문자로 정의한 것은 '상수' (변수는 변하는 값, 상수는 변하지 않는 값)
SCROLL_PAUSE_TIME = 1 # 페이지가 로드될 때까지 기다리는 시간
SEARCH_KEYWORD = 'python'

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())


driver.get('https://www.google.co.kr')
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEYWORD)
element.submit()


driver.find_element(by=By.LINK_TEXT, value='이미지').click()
time.sleep(SCROLL_PAUSE_TIME) # 페이지가 로그될 때까지 기다림



# 결과값 더보기
last_height = driver.execute_script('return document.body.scrollHeight')

scroll_cnt = 1

while True :
    # 윈도우 창을 0에서부터 가장 밑(scrollHeight까지 이동)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.body.scrollHeight')
    print(f'last_height: {last_height}, new_height: {new_height}, scroll_count: {scroll_cnt}')
    
    if last_height != new_height :
        last_height = new_height
        scroll_cnt += 1
    else:
        ### 해당 엘리먼트와 상호작용이 불가한 상태가 되면, ElementNotInteractableException 에외가 발생한다.
        element = driver.find_element(by=By.CSS_SELECTOR,value='#islmp > div > div > div > div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
        try :
            element.click()
            print('결과 더보기 클릭')
        except:
            break #더이상 스크롤 안되면 루프 빠져나오도록
# Out:
# last_height: 3752, new_height: 7875, scroll_count: 1
# last_height: 7875, new_height: 15873, scroll_count: 2
# last_height: 15873, new_height: 23145, scroll_count: 3
# last_height: 23145, new_height: 30659, scroll_count: 4
# last_height: 30659, new_height: 30740, scroll_count: 5
# last_height: 30740, new_height: 30740, scroll_count: 6
# 결과 더보기 클릭
# last_height: 30740, new_height: 37684, scroll_count: 6
# last_height: 37684, new_height: 39946, scroll_count: 7
# last_height: 39946, new_height: 39946, scroll_count: 8

# %% [markdown]
# ### 이미지 파일 추출하기

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# hyper-parameter : 대문자로 정의한 것은 '상수' (변수는 변하는 값, 상수는 변하지 않는 값)
SCROLL_PAUSE_TIME = 1 # 페이지가 로드될 때까지 기다리는 시간
SEARCH_KEYWORD = 'python'
IMAGE_EXTRACT_NUM = 10 #이미지 추출 개수


########################### 구글 접속 ###########################
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
driver.get('https://www.google.co.kr')


###########################   검색   ###########################
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEYWORD)
element.submit()


################# 이미지 검색결과 페이지로 이동 #################
driver.find_element(by=By.LINK_TEXT, value='이미지').click()
time.sleep(SCROLL_PAUSE_TIME) # 페이지가 로그될 때까지 기다림


################# 이미지 검색결과 페이지 스크롤 #################
last_height = driver.execute_script('return document.body.scrollHeight')
scroll_cnt = 1

while True :
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.body.scrollHeight')
#     print(f'last_height: {last_height}, new_height: {new_height}, scroll_count: {scroll_cnt}')
    
    if last_height != new_height :
        last_height = new_height
        scroll_cnt += 1
    else:
        element = driver.find_element(by=By.CSS_SELECTOR,value='#islmp > div > div > div > div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
        try :
            element.click()
            print('결과 더보기 클릭')
        except:
            break



################# 이미지 선택 & 해당 이미지 src 저장 #################
imgs = driver.find_elements(By.CSS_SELECTOR, '#islrg > div.islrc > div > a.wXeWr.islib.nfEiy')
# islrg > div.islrc > div:nth-child(2) > a.wXeWr.islib.nfEiy
# css selector 값의 :nth-child(#) : 동일한 태그로 리스트가 있을 경우, 리스트 중 특정한 값만 가리킴
# 따라서 전체 리스트를 가져오고자 할 경우에는 :nth-child(#)을 삭제한다.
# 키워드 변수 없이 위치 인수로 적어도 됨
print('이미지 개수: ', len(imgs))


img_src_list = []

img_cnt = 0
for cnt, img in enumerate(imgs, start=1):
    # img에는 a element가 들어가있음
    img.send_keys(Keys.ENTER)
    img_a = driver.find_element(By.CSS_SELECTOR, '#Sva75c > div.DyeYj > div > div.dFMRD > div.pxAole > div.tvh9oe.BIB1wf > c-wiz > div.nIWXKc.JgfpDb > div.OUZ5W > div.zjoqD > div.qdnLaf.isv-id.b0vFpe > div > a > img')
    img_src = img_a.get_attribute('src')
#     print(img_src)
    # beautifulSoup은 get(' ')이나 태그명[' ']으로 속성값을 가져왔었음.
    # Selenium에서는 get_attribute()을 사용
    # https://형식이 아닌 것도 있음 : 다시 요청할 수 없는, 내부에 저장된 이미지 값.
    # 재요청하려면 https://로 시작해야하므로 제외하기.
    if not img_src.startswith('http'):
        continue
    
    img_cnt += 1
    print(f'[{img_cnt}]: {img_src}')
    img_src_list.append(img_src)
    
    if img_cnt == IMAGE_EXTRACT_NUM:break
    
#Sva75c > div.DyeYj > div > div.dFMRD > div.pxAole > div.tvh9oe.BIB1wf > c-wiz > div.nIWXKc.JgfpDb > div.OUZ5W > div.zjoqD > div.qdnLaf.isv-id.b0vFpe > div > a > img
# Out:
# 결과 더보기 클릭
# 이미지 개수:  521
# [1]: https://blog.kakaocdn.net/dn/bQNMXI/btrRuovSulm/JAIE1s6DqBbaPX5bzddqw1/img.png
# [2]: https://blog.kakaocdn.net/dn/bL8ETY/btrsc1dKdvU/PKl3b1kLTKsKuWAY9u2XT1/img.png
# [3]: https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png
# [4]: https://devocean.sk.com/CKFinderJava/userfiles/images/python(3).png
# [5]: https://prepinsta.com/wp-content/uploads/2020/07/python-removebg-preview.webp
# [6]: https://media.geeksforgeeks.org/wp-content/cdn-uploads/20210917204112/Top-10-Advance-Python-Concepts-That-You-Must-Know.png
# [7]: https://www.freecodecamp.org/news/content/images/2022/02/Banner-10.png
# [8]: https://miro.medium.com/max/1400/1*FZWJzoMSaaMsE2qEb-jT9A.jpeg
# [9]: https://media.cnn.com/api/v1/images/stellar/prod/221224144245-01-python-found-austin-texas.jpg?c=original
# [10]: https://assets.entrepreneur.com/content/3x2/2000/1649279368-Ent-2022Python.jpeg?crop=4:3

# %% [markdown]
# ### 이미지 파일 저장하기

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# hyper-parameter : 대문자로 정의한 것은 '상수' (변수는 변하는 값, 상수는 변하지 않는 값)
SCROLL_PAUSE_TIME = 1 # 페이지가 로드될 때까지 기다리는 시간
SEARCH_KEYWORD = 'python'
IMAGE_EXTRACT_NUM = 10 #이미지 추출 개수


########################### 구글 접속 ###########################
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
driver.get('https://www.google.co.kr')


###########################   검색   ###########################
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEYWORD)
element.submit()


################# 이미지 검색결과 페이지로 이동 #################
driver.find_element(by=By.LINK_TEXT, value='이미지').click()
time.sleep(SCROLL_PAUSE_TIME) # 페이지가 로그될 때까지 기다림


################# 이미지 검색결과 페이지 스크롤 #################
last_height = driver.execute_script('return document.body.scrollHeight')
scroll_cnt = 1

while True :
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.body.scrollHeight')
#     print(f'last_height: {last_height}, new_height: {new_height}, scroll_count: {scroll_cnt}')
    
    if last_height != new_height :
        last_height = new_height
        scroll_cnt += 1
    else:
        element = driver.find_element(by=By.CSS_SELECTOR,value='#islmp > div > div > div > div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
        try :
            element.click()
            print('결과 더보기 클릭')
        except:
            break



################# 이미지 선택 & 해당 이미지 src 저장 #################
imgs = driver.find_elements(By.CSS_SELECTOR, '#islrg > div.islrc > div > a.wXeWr.islib.nfEiy')
print('이미지 개수: ', len(imgs))

img_src_list = []

img_cnt = 0
for cnt, img in enumerate(imgs, start=1):
    # img에는 a element가 들어가있음
    img.send_keys(Keys.ENTER)
    img_a = driver.find_element(By.CSS_SELECTOR, '#Sva75c > div.DyeYj > div > div.dFMRD > div.pxAole > div.tvh9oe.BIB1wf > c-wiz > div.nIWXKc.JgfpDb > div.OUZ5W > div.zjoqD > div.qdnLaf.isv-id.b0vFpe > div > a > img')
    img_src = img_a.get_attribute('src')

    if not img_src.startswith('http'):
        continue
    
    img_cnt += 1
    print(f'[{img_cnt}]: {img_src}')
    img_src_list.append(img_src)
    
    if img_cnt == IMAGE_EXTRACT_NUM:break
    


################# 검색 이미지 파일로 저장 #################
from bs4 import BeautifulSoup
import requests
import os

# c드라이브 > temp 폴더를 루트 디렉토리로 잡아 이미지를 저장
path = 'c:/Temp/'
# 시간을 원하는 형식으로 출력
ts = time.localtime() # time stamp
now = f'{ts.tm_year}.{ts.tm_mon}.{ts.tm_mday}.{ts.tm_hour}.{ts.tm_min}.{ts.tm_sec}'
directory = SEARCH_KEYWORD+'/'+now+'/' # python이라는 중간폴더 만든 것
# c:/Temp/python/2023.01.31.14.55.23/
os.chdir(path) #change directory 명령어를 수행하는 함수 # c:/Temp로 디렉토리를 변경하라

if not os.path.exists(directory):
    os.makedirs(directory)

    
file_no = 1
os.chdir(path+directory)

# 확장자명
for url in img_src_list:
    extension = url.split('.')[-1] # url로부터 추출한 file의 확장자명
    ext = ' ' # 최종적으로 file의 이름에 붙일 확장자
    if extension in ['jpg', 'JPG', 'jpeg', 'JPEG', 'png', 'PNG', 'gif', 'GIF']:
        ext = '.'+extension
    else:
        ext = '.jpg'
    # file 이름
    file_name = str(file_no) + '-'+ SEARCH_KEYWORD + ext

    res = requests.get(url)
    with open (file_name, 'wb') as f:
        # 디렉토리 정해놨으므로 파일 경로 없이 파일 이름만 명시해도 된다
        f.write(res.content)
    
    file_no +=1

driver.close()
# Out:
# 결과 더보기 클릭
# 이미지 개수:  525
# [1]: https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png
# [2]: https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/1280px-Python_logo_and_wordmark.svg.png
# [3]: https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png
# [4]: https://blog.kakaocdn.net/dn/bL8ETY/btrsc1dKdvU/PKl3b1kLTKsKuWAY9u2XT1/img.png
# [5]: https://prepinsta.com/wp-content/uploads/2020/07/python-removebg-preview.webp
# [6]: https://devblogs.microsoft.com/python/wp-content/uploads/sites/12/2022/07/July2022-InlayHints2-1-1024x639.png
# [7]: https://devocean.sk.com/CKFinderJava/userfiles/images/python(3).png
# [8]: https://www.freecodecamp.org/news/content/images/2022/02/Banner-10.png
# [9]: https://miro.medium.com/max/1400/1*FZWJzoMSaaMsE2qEb-jT9A.jpeg
# [10]: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRT8K1iKtgHHdzLczBOzRQbtWEtaY1dw9ya2Q&usqp=CAU

# %% [markdown]
# ## [실습] YES24 사이트에서 파이썬 도서 검색하기
# - yes24 사이트에서 파이썬 도서 검색 후, 평점이 9.6 이상인 도서의 제목과 가격, 평점 가져오기
#
# - Selenium으로 검색
# - BeautifulSoup으로 추출

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests


########################### yes24 접속 ###########################
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
driver.get('http://www.yes24.com/main/default.aspx')


########################### 파이썬 검색 ###########################
element = driver.find_element(by=By.ID, value='query')
element.send_keys('파이썬')
element.submit()
# <input type="text" title="YES24 검색어 입력" class="iptTxt iptTxtAd" accesskey="s" id="query" name="query" maxlength="80" value="" style="ime-mode: active;" autocomplete="off" onfocus="showLatestSearchList();" onkeydown="SearchBarRenderingEnableSet(false);init_searchbox();" onmousedown="SearchBarRenderingEnableSet(false);Common_init_searchbox();">
driver.find_element(by=By.CSS_SELECTOR, value='#stat_gb').click()
driver.find_element(by=By.CSS_SELECTOR, value='#stat_gb > option:nth-child(4)').click()


################# 평점 확인 #################
bs = BeautifulSoup(driver.page_source, 'html.parser')
# response.text가 아닌 driver.page_source에서 읽어온다
# print(bs)



point = bs.select('#yesSchList > li > div > div.item_info > div.info_row.info_rating > span.rating_grade > em')
title = bs.select('#yesSchList > li > div > div.item_info > div.info_row.info_name > a.gd_name')
price = bs.select('#yesSchList > li > div > div.item_info > div.info_row.info_price > strong > em')

# print(point[0].get_text()) #9.5
# print(title[0].get_text()) #Do it! 점프 투 파이썬
# print(price[0].get_text()) #19,800

idx=0
for i, p in enumerate(point):
    pnt = point[i].get_text()
    tit = title[i].get_text()
    prc = price[i].get_text()
    if float(pnt) >= 9.6:
        idx +=1
        print(f'[{idx}] 제목: {tit} | 가격: {prc} | 평점: {pnt}')
# Out:
# [1] 제목: Do it! 점프 투 파이썬, 가격: 16,920, 평점: 9.6
# [2] 제목: 혼자 공부하는 머신러닝+딥러닝, 가격: 23,400, 평점: 9.9
# [3] 제목: 만들면서 배우는 파이썬과 40개의 작품들, 가격: 16,920, 평점: 9.8
# [4] 제목: 혼자 공부하는 데이터 분석 with 파이썬, 가격: 23,400, 평점: 9.7
# [5] 제목: 데이터사이언스를 위한 기초 수학 with 파이썬, 가격: 27,000, 평점: 9.6
# [6] 제목: 파이썬 알고리즘 인터뷰, 가격: 34,200, 평점: 10.0
# [7] 제목: 차근차근 데이터 분석과 인공지능 with 파이썬, 가격: 23,000, 평점: 9.9
# [8] 제목: 1일 1로그 100일 완성 IT 지식, 가격: 18,000, 평점: 10.0
# [9] 제목: 미국 주식으로 시작하는 슬기로운 퀀트투자 (무료특별판), 가격: 0, 평점: 10.0
# [10] 제목: 일잘러의 비밀, 엑셀 대신 파이썬으로 업무 자동화하기, 가격: 21,600, 평점: 10.0
# [11] 제목: Do it! 알고리즘 코딩 테스트 - 파이썬 편 [체험판], 가격: 0, 평점: 9.8
# [12] 제목: 혼자 공부하는 파이썬 (개정판), 가격: 15,840, 평점: 10.0
# [13] 제목: 두근두근 파이썬, 가격: 25,000, 평점: 9.7
# [14] 제목: 이것이 취업을 위한 코딩 테스트다 with 파이썬, 가격: 27,200, 평점: 9.7

# %%
# A

########################### Selenium ###########################
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
# select라는 모듈 불러오기


driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
driver.get('http://www.yes24.com')

el = driver.find_element(By.ID, 'query')
el.send_keys('파이썬')
el.send_keys(Keys.ENTER)


# n개씩 보기
# select = Select(driver.find_element(By.ID, 'stat_gb'))
# select.select_by_index(3) # 1 : 하위 태그인 option 태그의 위치값 (0부터 시작)
# select.select_by_value('120') # 120 : option 태그의 value 속성의 값
# select.select_by_visible_text('120개씩 보기') # select 태그의 문자열 값, 즉 겉에 보여지는 텍스트

# yes24에서는 작동되지 않는다 : stat_gb라는 id를 가진 값이 많아서
# el = driver.find_element(By.ID, 'stat_gb')
# print(el.text)

select = Select(driver.find_elements(By.ID, 'stat_gb')[1])
select.select_by_visible_text('120개씩 보기')

# %%
########################### BeautifulSoup ###########################
from bs4 import BeautifulSoup

soup = BeautifulSoup(driver.page_source, 'html.parser')
# response.text가 아닌 driver.page_source에서 읽어온다
# print(bs)

book_list = soup.find('ul', attrs={'id':'yesSchList'})
books = book_list.find_all('li')

for i, book in enumerate(books):
    title = book.find('a', attrs={'class':'gd_name'})
    price = book.find('strong', attrs={'class':'txt_num'})
    # yes_b라는 클래스가 여러 개이므로 상위 태그를 찾아준 후 get_text
    rating = book.find('span', attrs={'class':'rating_grade'})
    if not rating: # 평점이 없는 도서인 경우 skip
        continue
    
    rating = rating.find('em', 'yes_b')
    if float(rating.get_text()) < 9.6 :
        continue
        
    print(f'{title.get_text()} | {price.get_text()} | {rating.get_text()}')
# Out:
# Do it! 점프 투 파이썬 | 16,920원 | 9.6
# 혼자 공부하는 머신러닝+딥러닝 | 23,400원 | 9.9
# 만들면서 배우는 파이썬과 40개의 작품들 | 16,920원 | 9.8
# 혼자 공부하는 데이터 분석 with 파이썬 | 23,400원 | 9.7
# 이것이 취업을 위한 코딩 테스트다 with 파이썬  | 30,600원 | 9.6
# 파이썬 머신러닝 완벽 가이드 | 36,000원 | 10.0
# 1일 1로그 100일 완성 IT 지식 | 18,000원 | 9.9
# Do it! 게임 10개 만들며 배우는 파이썬 | 19,800원 | 10.0
# 혼자 공부하는 파이썬 (개정판) | 15,840원 | 10.0
# 이것이 취업을 위한 코딩 테스트다 with 파이썬 | 27,200원 | 10.0
# Do it! 첫 파이썬 | 12,600원 | 9.8
# Do it! 쉽게 배우는 파이썬 데이터 분석 | 20,700원 | 10.0
# 모두의 파이썬 | 10,800원 | 9.7
# Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편 | 19,800원 | 9.7

# %% [markdown]
# # X Path 요소로 찾기

# %%
# 뉴스의 제목 및 내용 스크랩핑

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
driver.get('https://news.naver.com')

xpath = '//*[@id="ct"]/div/section[1]/div[2]/div/div[1]/div[2]/div[1]/div/div[2]/a'

elem = driver.find_element(by=By.XPATH, value=xpath)
print('제목: ', elem.find_element(by=By.CLASS_NAME, value='cjs_t').text)
print('내용: ', elem.find_element(By.CLASS_NAME, 'cjs_d').text)
# get_text()는 BeautifulSoup. Selenium에서는 text 이용.


# //*[@id="ct"]/div/section[1]/div[2]/div/div[1]/div[2]/div[1]/div/div[2]/a
# <div class="cjs_t">'김연경·남진 응원' 인증했던 김기현, "새빨간 거짓말" 역풍</div>
# <p class="cjs_d">남진 측 인터뷰 등으로 상황 반전... 안철수·윤상현 이어 민주당까지 비판 가세 ▲ 국민의힘 당권 주자인 김기현 의원이 27일 자신의 페이스북에 여자 배구 김연경, 가수 남진과 함께 찍은 사진을 공개했다. ⓒ 김기현</p>
# Out:
# 제목:  국민의힘 당대표 가상 양자대결… 安 60.5% vs 金 37.1% [창간34 여론조사]
# 내용:  세계일보·한국갤럽 여론조사 安, TK 등 텃밭서 당권 경쟁 압도 전체 응답서도 28.7%P차로 앞서 安, 제주·무직·은퇴자 제외 전 항목 강세 지역별·성별·직업별·정치성향별 우위 10·20·30대 安 지지… 60세
