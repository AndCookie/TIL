# %% [markdown]
# # 데이터 로드

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글세팅
# 브랜드별 색상 팔레트 지정
colors = {'biobidet':'firebrick', 'brondell': 'coral', 'tushy':'gold', 'toto': 'lightgreen', 'ovedecors':'seagreen', 'alphabidet':'skyblue', 'kohler': 'royalblue', 'bidetmate':'mediumpurple', 'a_s': 'indigo', 'vovo':'black'}
# 채널별 색상 팔레트 지정
channel = {'costco':'black', 'amazon': 'darkgrey', 'build.com':'darkgoldenrod', 'walmart': 'gold', 'hd':'yellow', 'lowes':'orange'}

combined_review_origin = pd.read_excel('combined_review.xlsx')
combined_review_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30555 entries, 0 to 30554
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     30555 non-null  object
#  1   고유 제품명  30555 non-null  object
#  2   형태      30555 non-null  object
#  3   작성일     30555 non-null  datetime64[ns]
#  4   별점      30555 non-null  int64
#  5   제목_본문   30555 non-null  object
#  6   채널명     30555 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1.6+ MB

# %%
# 카피본 떠놓고 시작하기
combined_review = combined_review_origin.copy()
combined_review.shape
# Out:
# (30555, 7)

# %%
combined_review['작성일']
# Out:
# 0       2016-12-01
# 1       2016-11-06
# 2       2019-09-17
# 3       2020-10-02
# 4       2019-05-13
#            ...
# 30550   2022-02-03
# 30551   2022-06-03
# 30552   2022-06-03
# 30553   2020-11-30
# 30554   2021-11-30
# Name: 작성일, Length: 30555, dtype: datetime64[ns]

# %% [markdown]
# # 시계열 판매량 추이

# %% [markdown]
# ## 리뷰개수

# %%
# 분기별/연도별로 날짜를 그룹화하고 리뷰 개수를 계산
combined_review['리뷰수'] = 1
combined_review['연도'] = combined_review['작성일'].dt.to_period("Y")
combined_review['분기'] = combined_review['작성일'].dt.to_period("Q")
combined_review
# Out:
#              회사명  고유 제품명 형태        작성일  별점  \
# 0       biobidet   BB A8  E 2016-12-01   5
# 1       biobidet   BB A8  E 2016-11-06   5
# 2       biobidet   BB A8  E 2019-09-17   5
# 3       biobidet   BB A8  E 2020-10-02   4
# 4       biobidet   BB A8  E 2019-05-13   5
# ...          ...     ... ..        ...  ..
# 30550  ovedecors  Irenne  E 2022-02-03   5
# 30551  ovedecors  Irenne  E 2022-06-03   5
# 30552  ovedecors  Irenne  E 2022-06-03   4
# 30553  ovedecors  Irenne  E 2020-11-30   5
# 30554  ovedecors  Irenne  E 2021-11-30   5
#
#                                                    제목_본문     채널명  리뷰수    연도  \
# 0      AMAZING.I couldn’t be happier!!! A must for an...   lowes    1  2016
# 1      Good Product!.It takes just minutes to install...   lowes    1  2016
# 2      Very Satisfied....Love the night glow light. V...   lowes    1  2019
# 3      Great features and easy to install.Steady hot ...   lowes    1  2020
# 4      Wonderful features.I bought 10 days ago and us...   lowes    1  2019
# ...                                                  ...     ...  ...   ...
# 30550  Worth every penny.We love our new toilet! We h...  costco    1  2022
# 30551  Worth every penny!.It’s a beautiful toilet tha...  costco    1  2022
# 30552  Worth it.I’ve had this for a couple weeks now ...  costco    1  2022
# 30553  You will miss this.Good but needs some tweakin...  costco    1  2020
# 30554  You’re mad if you didn’t buy this... :).Easy i...  costco    1  2021
#
#            분기
# 0      2016Q4
# 1      2016Q4
# 2      2019Q3
# 3      2020Q4
# 4      2019Q2
# ...       ...
# 30550  2022Q1
# 30551  2022Q2
# 30552  2022Q2
# 30553  2020Q4
# 30554  2021Q4
#
# [30555 rows x 10 columns]

# %%
df1 = combined_review.groupby('연도').count().reset_index()[['연도', '리뷰수']]
df1['연도'] = df1['연도'].astype(str)
df1 = df1.loc[7:]
# df1 = df1.loc[29:]
df1
# Out:
#       연도   리뷰수
# 7   2016   814
# 8   2017  1643
# 9   2018  3888
# 10  2019  4875
# 11  2020  9166
# 12  2021  4316
# 13  2022  4782

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(12,8))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='구매건수', marker='o')
plt.plot(df1['연도'], df1['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('연도별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %% [markdown]
# ## 작성일자

# %% [markdown]
# ### 채널별 리뷰 작성일자

# %%
combined_review['채널명'].unique()
# Out:
# array(['lowes', 'build.com', 'amazon', 'walmart', 'hd', 'costco'],
#       dtype=object)

# %%
combined_review[combined_review['채널명']=='amazon']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#  '2018', '2019', '2020', '2021', '2022']
# Length: 14, dtype: period[A-DEC]

# %%
combined_review[combined_review['채널명']=='build.com']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
# Length: 8, dtype: period[A-DEC]

# %%
combined_review[combined_review['채널명']=='costco']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#  '2019', '2020', '2021', '2022']
# Length: 13, dtype: period[A-DEC]

# %%
combined_review[combined_review['채널명']=='hd']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#  '2021', '2022']
# Length: 11, dtype: period[A-DEC]

# %%
combined_review[combined_review['채널명']=='lowes']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2012', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#  '2022']
# Length: 10, dtype: period[A-DEC]

# %%
combined_review[combined_review['채널명']=='walmart']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
# Length: 8, dtype: period[A-DEC]

# %% [markdown]
# ### 브랜드별 리뷰 작성일자

# %%
combined_review[combined_review['회사명']=='alphabidet']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
# Length: 8, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='a_s']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2017', '2018', '2019', '2020', '2021', '2022']
# Length: 6, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='bidetmate']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2020', '2021', '2022']
# Length: 3, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='biobidet']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#  '2018', '2019', '2020', '2021', '2022']
# Length: 14, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='brondell']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#  '2019', '2020', '2021', '2022']
# Length: 13, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='kohler']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
# Length: 8, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='ovedecors']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2019', '2020', '2021', '2022']
# Length: 4, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='toto']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#  '2022']
# Length: 10, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='tushy']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2018', '2019', '2020', '2021', '2022']
# Length: 5, dtype: period[A-DEC]

# %%
combined_review[combined_review['회사명']=='vovo']['연도'].sort_values().unique()
# Out:
# <PeriodArray>
# ['2021', '2022']
# Length: 2, dtype: period[A-DEC]

# %% [markdown]
# ## 채널별 리뷰개수

# %%
df2 = combined_review.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
df2['연도'] = df2['연도'].astype(str)
df2
# Out:
#       연도        채널명   리뷰수
# 0   2009     amazon     2
# 1   2010     amazon     4
# 2   2010     costco     4
# 3   2011     amazon     6
# 4   2011     costco     3
# ..   ...        ...   ...
# 59  2022  build.com   183
# 60  2022     costco  2541
# 61  2022         hd   110
# 62  2022      lowes    99
# 63  2022    walmart    90
#
# [64 rows x 3 columns]

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=df2, palette='Set2', dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('채널별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 코스트코

# %%
df3 = combined_review[combined_review['채널명']=='costco']
df3
# Out:
#              회사명     고유 제품명 형태        작성일  별점  \
# 12892   biobidet  BB Elite3  A 2020-11-29   5
# 12893   biobidet  BB Elite3  A 2018-11-30   4
# 12894   biobidet  BB Elite3  A 2020-11-29   5
# 12895   biobidet  BB Elite3  A 2019-11-30   5
# 12896   biobidet  BB Elite3  A 2020-11-29   5
# ...          ...        ... ..        ...  ..
# 30550  ovedecors     Irenne  E 2022-02-03   5
# 30551  ovedecors     Irenne  E 2022-06-03   5
# 30552  ovedecors     Irenne  E 2022-06-03   4
# 30553  ovedecors     Irenne  E 2020-11-30   5
# 30554  ovedecors     Irenne  E 2021-11-30   5
#
#                                                    제목_본문     채널명  리뷰수    연도  \
# 12892  I ordered this about 2 weeks ago. I originally...  costco    1  2020
# 12893       It good for what it does - but darn it Cold.  costco    1  2018
# 12894  I bought this a few months ago and love it. It...  costco    1  2020
# 12895  We have been using bidets for years now in jus...  costco    1  2019
# 12896  I bought this and I got it in the mail. I put ...  costco    1  2020
# ...                                                  ...     ...  ...   ...
# 30550  Worth every penny.We love our new toilet! We h...  costco    1  2022
# 30551  Worth every penny!.It’s a beautiful toilet tha...  costco    1  2022
# 30552  Worth it.I’ve had this for a couple weeks now ...  costco    1  2022
# 30553  You will miss this.Good but needs some tweakin...  costco    1  2020
# 30554  You’re mad if you didn’t buy this... :).Easy i...  costco    1  2021
#
#            분기
# 12892  2020Q4
# 12893  2018Q4
# 12894  2020Q4
# 12895  2019Q4
# 12896  2020Q4
# ...       ...
# 30550  2022Q1
# 30551  2022Q2
# 30552  2022Q2
# 30553  2020Q4
# 30554  2021Q4
#
# [17663 rows x 10 columns]

# %%
df31 = df3.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df31['분기'] = df31['분기'].astype(str)
df31 = df31.loc[7:]
df31
# Out:
#         분기   리뷰수
# 7   2017Q4   706
# 8   2018Q4  2873
# 9   2019Q4  3336
# 10  2020Q4  6323
# 11  2021Q4  1483
# 12  2022Q1  1201
# 13  2022Q2   484
# 14  2022Q3   510
# 15  2022Q4   346

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(10,6))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='리뷰수', marker='o')
plt.plot(df31['분기'], df31['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('코스트코_분기별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df32 = df3.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df32['연도'] = df32['연도'].astype(str)
df32 = df32.loc[12:]
df32
# Out:
#       연도        회사명   리뷰수
# 12  2017   biobidet   346
# 13  2017   brondell   360
# 14  2018   biobidet  2127
# 15  2018   brondell   746
# 16  2019   biobidet  2539
# 17  2019   brondell   717
# 18  2019  ovedecors    80
# 19  2020   biobidet  4547
# 20  2020   brondell  1589
# 21  2020  ovedecors   187
# 22  2021   biobidet  1096
# 23  2021   brondell   273
# 24  2021     kohler    12
# 25  2021  ovedecors   102
# 26  2022   biobidet  1686
# 27  2022   brondell   681
# 28  2022     kohler    98
# 29  2022  ovedecors    76

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df32['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df32, palette=palette, dodge=False)
plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('채널별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 코스트코 제외

# %%
df4 = combined_review[combined_review['채널명']!='costco']
df4
# Out:
#             회사명 고유 제품명 형태        작성일  별점  \
# 0      biobidet  BB A8  E 2016-12-01   5
# 1      biobidet  BB A8  E 2016-11-06   5
# 2      biobidet  BB A8  E 2019-09-17   5
# 3      biobidet  BB A8  E 2020-10-02   4
# 4      biobidet  BB A8  E 2019-05-13   5
# ...         ...    ... ..        ...  ..
# 12887  brondell  S1400  R 2022-04-20   2
# 12888  brondell  S1400  R 2022-04-28   1
# 12889  brondell  S1400  R 2022-05-05   5
# 12890  brondell  S1400  R 2022-06-23   5
# 12891  brondell  S1400  R 2022-10-05   1
#
#                                                    제목_본문    채널명  리뷰수    연도  \
# 0      AMAZING.I couldn’t be happier!!! A must for an...  lowes    1  2016
# 1      Good Product!.It takes just minutes to install...  lowes    1  2016
# 2      Very Satisfied....Love the night glow light. V...  lowes    1  2019
# 3      Great features and easy to install.Steady hot ...  lowes    1  2020
# 4      Wonderful features.I bought 10 days ago and us...  lowes    1  2019
# ...                                                  ...    ...  ...   ...
# 12887  This bidet toilet seat has some functional dra...     hd    1  2022
# 12888  Beware! Be carefull.  Support not helpful.Befo...     hd    1  2022
# 12889  Great Product.A bidet which works very well an...     hd    1  2022
# 12890  Only way to go, literally.After using a Bronde...     hd    1  2022
# 12891  I will be returning this Bidet  the seat is......     hd    1  2022
#
#            분기
# 0      2016Q4
# 1      2016Q4
# 2      2019Q3
# 3      2020Q4
# 4      2019Q2
# ...       ...
# 12887  2022Q2
# 12888  2022Q2
# 12889  2022Q2
# 12890  2022Q2
# 12891  2022Q4
#
# [12892 rows x 10 columns]

# %%
df41 = df4.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df41['분기'] = df41['분기'].astype(str)
df41 = df41.loc[28:]
df41
# Out:
#         분기  리뷰수
# 28  2017Q1  256
# 29  2017Q2  208
# 30  2017Q3  219
# 31  2017Q4  254
# 32  2018Q1  247
# 33  2018Q2  215
# 34  2018Q3  238
# 35  2018Q4  315
# 36  2019Q1  401
# 37  2019Q2  341
# 38  2019Q3  392
# 39  2019Q4  405
# 40  2020Q1  682
# 41  2020Q2  711
# 42  2020Q3  683
# 43  2020Q4  767
# 44  2021Q1  889
# 45  2021Q2  705
# 46  2021Q3  614
# 47  2021Q4  625
# 48  2022Q1  671
# 49  2022Q2  584
# 50  2022Q3  610
# 51  2022Q4  376

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(12,8))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='구매건수', marker='o')
plt.plot(df41['분기'], df41['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('코스트코 제외_연도별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df42 = df4.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df42['연도'] = df42['연도'].astype(str)
df42 = df42.loc[12:]
df42
# Out:
#       연도         회사명   리뷰수
# 12  2015    brondell    23
# 13  2015      kohler     3
# 14  2015        toto     8
# 15  2016  alphabidet    16
# 16  2016    biobidet   636
# 17  2016    brondell    33
# 18  2016      kohler     1
# 19  2016        toto    14
# 20  2017         a_s    81
# 21  2017  alphabidet    35
# 22  2017    biobidet   603
# 23  2017    brondell   187
# 24  2017      kohler    17
# 25  2017        toto    14
# 26  2018         a_s     6
# 27  2018  alphabidet    38
# 28  2018    biobidet   503
# 29  2018    brondell   291
# 30  2018      kohler    18
# 31  2018        toto    55
# 32  2018       tushy   104
# 33  2019         a_s    56
# 34  2019  alphabidet    33
# 35  2019    biobidet   665
# 36  2019    brondell   362
# 37  2019      kohler     4
# 38  2019        toto   165
# 39  2019       tushy   254
# 40  2020         a_s    19
# 41  2020  alphabidet    58
# 42  2020   bidetmate    40
# 43  2020    biobidet  1251
# 44  2020    brondell   762
# 45  2020      kohler    57
# 46  2020        toto   236
# 47  2020       tushy   420
# 48  2021         a_s     2
# 49  2021  alphabidet    98
# 50  2021   bidetmate   115
# 51  2021    biobidet   902
# 52  2021    brondell   618
# 53  2021      kohler    68
# 54  2021        toto   512
# 55  2021       tushy   445
# 56  2021        vovo    73
# 57  2022         a_s     6
# 58  2022  alphabidet   145
# 59  2022   bidetmate    87
# 60  2022    biobidet   442
# 61  2022    brondell   316
# 62  2022      kohler    75
# 63  2022        toto   520
# 64  2022       tushy   622
# 65  2022        vovo    28

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df42['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df42, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('코스트코 제외_연도별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 아마존

# %%
df5 = combined_review[combined_review['채널명']=='amazon']
df5
# Out:
#               회사명       고유 제품명 형태        작성일  별점  \
# 2540        tushy    Basic 2.0  A 2022-12-06   5
# 2541        tushy    Basic 2.0  A 2022-12-06   5
# 2542   alphabidet     Alpha JX  R 2022-12-06   5
# 2543        tushy  Classic 3.0  A 2022-12-06   5
# 2544        tushy  Classic 3.0  A 2022-12-06   3
# ...           ...          ... ..        ...  ..
# 11147    biobidet        BB600  E 2010-03-30   3
# 11148    biobidet        BB600  E 2010-01-17   5
# 11149    biobidet        BB600  E 2010-01-11   5
# 11150    biobidet        BB600  E 2009-07-28   2
# 11151    biobidet        BB600  E 2009-04-12   5
#
#                                                    제목_본문     채널명  리뷰수    연도  \
# 2540       Pour le grande toilette et pas sentir le cul.  amazon    1  2022
# 2541   Cleanliness.My husband loves this contraption!...  amazon    1  2022
# 2542   The whole family loves the bidet..I don’t know...  amazon    1  2022
# 2543   Life changing.I feel like a damn queen, how di...  amazon    1  2022
# 2544   Not for women.I read the questions on this ite...  amazon    1  2022
# ...                                                  ...     ...  ...   ...
# 11147  Love that warm seat, but a buyer should know.....  amazon    1  2010
# 11148  Nice features for the money..I am very pleased...  amazon    1  2010
# 11149  Bio Bidet Supreme BB 1000 Bidet.The Bio Bidet ...  amazon    1  2010
# 11150  Not very durable.We bought ours in 2006, it on...  amazon    1  2009
# 11151  BB-1000 is the BEST!.Once you use one of these...  amazon    1  2009
#
#            분기
# 2540   2022Q4
# 2541   2022Q4
# 2542   2022Q4
# 2543   2022Q4
# 2544   2022Q4
# ...       ...
# 11147  2010Q1
# 11148  2010Q1
# 11149  2010Q1
# 11150  2009Q3
# 11151  2009Q2
#
# [8612 rows x 10 columns]

# %%
df51 = df5.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df51['분기'] = df51['분기'].astype(str)
df51 = df51.loc[28:]
df51
# Out:
#         분기  리뷰수
# 28  2017Q1   66
# 29  2017Q2   57
# 30  2017Q3   55
# 31  2017Q4   78
# 32  2018Q1  120
# 33  2018Q2  141
# 34  2018Q3  182
# 35  2018Q4  223
# 36  2019Q1  272
# 37  2019Q2  268
# 38  2019Q3  290
# 39  2019Q4  265
# 40  2020Q1  507
# 41  2020Q2  369
# 42  2020Q3  399
# 43  2020Q4  522
# 44  2021Q1  635
# 45  2021Q2  479
# 46  2021Q3  470
# 47  2021Q4  497
# 48  2022Q1  490
# 49  2022Q2  430
# 50  2022Q3  510
# 51  2022Q4  329

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(10,6))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='리뷰수', marker='o')
plt.plot(df51['분기'], df51['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('아마존_분기별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df52 = df5.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df52['연도'] = df52['연도'].astype(str)
df52 = df52.loc[14:]
df52
# Out:
#       연도         회사명  리뷰수
# 14  2017  alphabidet   35
# 15  2017    biobidet  160
# 16  2017    brondell   47
# 17  2017        toto   14
# 18  2018  alphabidet   23
# 19  2018    biobidet  324
# 20  2018    brondell  160
# 21  2018        toto   55
# 22  2018       tushy  104
# 23  2019  alphabidet   25
# 24  2019    biobidet  477
# 25  2019    brondell  176
# 26  2019        toto  163
# 27  2019       tushy  254
# 28  2020  alphabidet   47
# 29  2020   bidetmate   40
# 30  2020    biobidet  801
# 31  2020    brondell  268
# 32  2020        toto  221
# 33  2020       tushy  420
# 34  2021  alphabidet   92
# 35  2021   bidetmate  115
# 36  2021    biobidet  622
# 37  2021    brondell  359
# 38  2021        toto  448
# 39  2021       tushy  445
# 40  2022  alphabidet  138
# 41  2022   bidetmate   87
# 42  2022    biobidet  264
# 43  2022    brondell  215
# 44  2022        toto  433
# 45  2022       tushy  622

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df52['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df52, palette=palette, dodge=False)
plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('아마존_연도별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 빌드컴

# %%
df6 = combined_review[combined_review['채널명']=='build.com']
df6
# Out:
#            회사명       고유 제품명 형태        작성일  별점  \
# 1046  biobidet       BB2000  R 2015-01-09   5
# 1047  biobidet       BB2000  R 2015-01-09   5
# 1048  biobidet       BB2000  R 2015-04-04   4
# 1049  biobidet       BB2000  R 2015-04-08   5
# 1050  biobidet       BB2000  R 2015-04-09   5
# ...        ...          ... ..        ...  ..
# 2535      toto  SW3046 S500  E 2022-01-21   5
# 2536      toto  SW3046 S500  E 2022-04-10   5
# 2537      toto  SW3046 S500  E 2022-05-04   5
# 2538      toto  SW3046 S500  E 2022-06-17   5
# 2539      toto  SW3046 S500  E 2022-06-25   5
#
#                                                   제목_본문        채널명  리뷰수    연도  \
# 1046     Better then Toto .Had toto for a long time....  build.com    1  2015
# 1047     We should have bought one years ago! .We bo...  build.com    1  2015
# 1048     A must have. .Owned a model BB1000 since fe...  build.com    1  2015
# 1049     Everyone should have one! .We've had ours i...  build.com    1  2015
# 1050     Excellent product .I am a residential archi...  build.com    1  2015
# ...                                                 ...        ...  ...   ...
# 2535     Excellent Washlet, confusing remote .Pros: ...  build.com    1  2022
# 2536     Great bidet seat .We highly recommend this ...  build.com    1  2022
# 2537     Why would u buy this great product .Best in...  build.com    1  2022
# 2538     Excellent quality .This is a high quality s...  build.com    1  2022
# 2539     Pleased with our Washlet+! .We are really h...  build.com    1  2022
#
#           분기
# 1046  2015Q1
# 1047  2015Q1
# 1048  2015Q2
# 1049  2015Q2
# 1050  2015Q2
# ...      ...
# 2535  2022Q1
# 2536  2022Q2
# 2537  2022Q2
# 2538  2022Q2
# 2539  2022Q2
#
# [1494 rows x 10 columns]

# %%
df61 = df6.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df61['분기'] = df61['분기'].astype(str)
df61 = df61.loc[7:]
df61
# Out:
#         분기  리뷰수
# 7   2017Q1   75
# 8   2017Q2   58
# 9   2017Q3   60
# 10  2017Q4   81
# 11  2018Q1   32
# 12  2018Q2   23
# 13  2018Q3   13
# 14  2018Q4   27
# 15  2019Q1   33
# 16  2019Q2   16
# 17  2019Q3   50
# 18  2019Q4   49
# 19  2020Q1   52
# 20  2020Q2  111
# 21  2020Q3  102
# 22  2020Q4  100
# 23  2021Q1   92
# 24  2021Q2   58
# 25  2021Q3   46
# 26  2021Q4   61
# 27  2022Q1   78
# 28  2022Q2   51
# 29  2022Q3   33
# 30  2022Q4   21

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(10,6))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='리뷰수', marker='o')
plt.plot(df61['분기'], df61['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('빌드컴_분기별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df62 = df6.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df62['연도'] = df62['연도'].astype(str)
df62 = df62.loc[4:]
df62
# Out:
#       연도       회사명  리뷰수
# 4   2017       a_s   40
# 5   2017  biobidet  183
# 6   2017  brondell   34
# 7   2017    kohler   17
# 8   2018       a_s    3
# 9   2018  biobidet   54
# 10  2018  brondell   20
# 11  2018    kohler   18
# 12  2019       a_s   53
# 13  2019  biobidet   72
# 14  2019  brondell   19
# 15  2019    kohler    4
# 16  2020       a_s   17
# 17  2020  biobidet  191
# 18  2020  brondell  112
# 19  2020    kohler   39
# 20  2020      toto    6
# 21  2021       a_s    2
# 22  2021  biobidet  119
# 23  2021  brondell   67
# 24  2021    kohler   53
# 25  2021      toto   16
# 26  2022       a_s    5
# 27  2022  biobidet   66
# 28  2022  brondell   16
# 29  2022    kohler   56
# 30  2022      toto   40

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df62['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df62, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('빌드컴_연도별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 홈디포

# %%
df7 = combined_review[combined_review['채널명']=='hd']
df7
# Out:
#             회사명 고유 제품명 형태        작성일  별점  \
# 12058  brondell  SE600  R 2017-09-20   5
# 12059  brondell  SE600  R 2018-01-03   3
# 12060  brondell  SE600  R 2018-01-03   5
# 12061  brondell  SE600  R 2018-01-24   5
# 12062  brondell  SE600  R 2018-02-02   5
# ...         ...    ... ..        ...  ..
# 12887  brondell  S1400  R 2022-04-20   2
# 12888  brondell  S1400  R 2022-04-28   1
# 12889  brondell  S1400  R 2022-05-05   5
# 12890  brondell  S1400  R 2022-06-23   5
# 12891  brondell  S1400  R 2022-10-05   1
#
#                                                    제목_본문 채널명  리뷰수    연도  \
# 12058  Best money ever spent!.Bought this with specul...  hd    1  2017
# 12059  I like the fact that it has a remote. I chose ...  hd    1  2018
# 12060  Amazing!.This product is amazing! I had never ...  hd    1  2018
# 12061  Totally groovy.Excellent product!  Very easy i...  hd    1  2018
# 12062  Brondell Se600 bidet.Excellent. Fairly priced....  hd    1  2018
# ...                                                  ...  ..  ...   ...
# 12887  This bidet toilet seat has some functional dra...  hd    1  2022
# 12888  Beware! Be carefull.  Support not helpful.Befo...  hd    1  2022
# 12889  Great Product.A bidet which works very well an...  hd    1  2022
# 12890  Only way to go, literally.After using a Bronde...  hd    1  2022
# 12891  I will be returning this Bidet  the seat is......  hd    1  2022
#
#            분기
# 12058  2017Q3
# 12059  2018Q1
# 12060  2018Q1
# 12061  2018Q1
# 12062  2018Q1
# ...       ...
# 12887  2022Q2
# 12888  2022Q2
# 12889  2022Q2
# 12890  2022Q2
# 12891  2022Q4
#
# [834 rows x 10 columns]

# %%
df71 = df7.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df71['분기'] = df71['분기'].astype(str)
df71 = df71.loc[12:]
df71
# Out:
#         분기  리뷰수
# 12  2017Q1   19
# 13  2017Q2   10
# 14  2017Q3   23
# 15  2017Q4    8
# 16  2018Q1   42
# 17  2018Q2   22
# 18  2018Q3   22
# 19  2018Q4   34
# 20  2019Q1   51
# 21  2019Q2   29
# 22  2019Q3   26
# 23  2019Q4   44
# 24  2020Q1   42
# 25  2020Q2   74
# 26  2020Q3   55
# 27  2020Q4   41
# 28  2021Q1   43
# 29  2021Q2   53
# 30  2021Q3   36
# 31  2021Q4   16
# 32  2022Q1   33
# 33  2022Q2   54
# 34  2022Q3   14
# 35  2022Q4    9

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(10,6))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='리뷰수', marker='o')
plt.plot(df71['분기'], df71['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('홈디포_분기별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df72 = df7.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df72['연도'] = df72['연도'].astype(str)
df72 = df72.loc[5:]
df72
# Out:
#       연도         회사명  리뷰수
# 5   2017    biobidet   37
# 6   2017    brondell   23
# 7   2018  alphabidet   15
# 8   2018    biobidet   58
# 9   2018    brondell   47
# 10  2019  alphabidet    8
# 11  2019    biobidet   19
# 12  2019    brondell  121
# 13  2019        toto    2
# 14  2020  alphabidet   11
# 15  2020    biobidet   30
# 16  2020    brondell  162
# 17  2020        toto    9
# 18  2021  alphabidet    6
# 19  2021    biobidet   21
# 20  2021    brondell   73
# 21  2021        toto   48
# 22  2022  alphabidet    7
# 23  2022    biobidet    9
# 24  2022    brondell   47
# 25  2022        toto   47

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df72['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df72, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('홈디포_연도별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 로우스

# %%
df8 = combined_review[combined_review['채널명']=='lowes']
df8
# Out:
#            회사명 고유 제품명 형태        작성일  별점  \
# 0     biobidet  BB A8  E 2016-12-01   5
# 1     biobidet  BB A8  E 2016-11-06   5
# 2     biobidet  BB A8  E 2019-09-17   5
# 3     biobidet  BB A8  E 2020-10-02   4
# 4     biobidet  BB A8  E 2019-05-13   5
# ...        ...    ... ..        ...  ..
# 1041  brondell  CL510  R 2018-12-02   5
# 1042  brondell  CL510  R 2020-04-02   5
# 1043  brondell  CL510  R 2021-01-04   5
# 1044  brondell  CL510  R 2019-10-30   5
# 1045  brondell  CL510  R 2020-11-27   5
#
#                                                   제목_본문    채널명  리뷰수    연도  \
# 0     AMAZING.I couldn’t be happier!!! A must for an...  lowes    1  2016
# 1     Good Product!.It takes just minutes to install...  lowes    1  2016
# 2     Very Satisfied....Love the night glow light. V...  lowes    1  2019
# 3     Great features and easy to install.Steady hot ...  lowes    1  2020
# 4     Wonderful features.I bought 10 days ago and us...  lowes    1  2019
# ...                                                 ...    ...  ...   ...
# 1041  Easy to Install.I never bought a bidet until n...  lowes    1  2018
# 1042  One of the best investments ever!.Bought the S...  lowes    1  2020
# 1043  Bidet toilet seat is amazing!!!!.this is so am...  lowes    1  2021
# 1044  Perfect wash with the Brondell Swash!.Can anyo...  lowes    1  2019
# 1045  Excellent performance, easy installation. NICE...  lowes    1  2020
#
#           분기
# 0     2016Q4
# 1     2016Q4
# 2     2019Q3
# 3     2020Q4
# 4     2019Q2
# ...      ...
# 1041  2018Q4
# 1042  2020Q2
# 1043  2021Q1
# 1044  2019Q4
# 1045  2020Q4
#
# [1046 rows x 10 columns]

# %%
df81 = df8.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df81['분기'] = df81['분기'].astype(str)
df81 = df81.loc[12:]
df81
# Out:
#         분기  리뷰수
# 12  2017Q1   30
# 13  2017Q2   32
# 14  2017Q3   48
# 15  2017Q4   66
# 16  2018Q1   38
# 17  2018Q2   18
# 18  2018Q3   14
# 19  2018Q4   10
# 20  2019Q1   14
# 21  2019Q2   13
# 22  2019Q3   15
# 23  2019Q4   22
# 24  2020Q1   40
# 25  2020Q2   82
# 26  2020Q3   61
# 27  2020Q4   58
# 28  2021Q1   72
# 29  2021Q2   78
# 30  2021Q3   36
# 31  2021Q4   28
# 32  2022Q1   35
# 33  2022Q2   25
# 34  2022Q3   32
# 35  2022Q4    7

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(10,6))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='리뷰수', marker='o')
plt.plot(df81['분기'], df81['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('로우스_분기별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df82 = df8.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df82['연도'] = df82['연도'].astype(str)
df82 = df82.loc[6:]
df82
# Out:
#       연도       회사명  리뷰수
# 6   2017       a_s   41
# 7   2017  biobidet   66
# 8   2017  brondell   69
# 9   2018       a_s    3
# 10  2018  biobidet   19
# 11  2018  brondell   58
# 12  2019       a_s    3
# 13  2019  biobidet   20
# 14  2019  brondell   41
# 15  2020       a_s    2
# 16  2020  biobidet   41
# 17  2020  brondell  180
# 18  2020    kohler   18
# 19  2021  biobidet   33
# 20  2021  brondell   93
# 21  2021    kohler   15
# 22  2021      vovo   73
# 23  2022       a_s    1
# 24  2022  biobidet   22
# 25  2022  brondell   29
# 26  2022    kohler   19
# 27  2022      vovo   28

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df82['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df82, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('로우스_연도별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 월마트

# %%
df9 = combined_review[combined_review['채널명']=='walmart']
df9
# Out:
#             회사명  고유 제품명 형태        작성일  별점  \
# 11152  biobidet   BB800  E 2017-01-01   5
# 11153  biobidet  BB1700  E 2017-01-01   5
# 11154  biobidet  BB2000  E 2020-01-01   5
# 11155  biobidet   BB600  R 2019-01-10   5
# 11156  biobidet   BB600  R 2021-01-10   5
# ...         ...     ... ..        ...  ..
# 12053  biobidet  BB1700  E 2015-09-08   5
# 12054  biobidet     DIB  R 2016-09-08   3
# 12055  biobidet     DIB  R 2016-09-08   5
# 12056  biobidet  BB1700  E 2017-09-08   5
# 12057  biobidet     DIB  R 2016-09-09   5
#
#                                                    제목_본문      채널명  리뷰수    연도  \
# 11152  Luxury at an affordable price!.We just purchas...  walmart    1  2017
# 11153  Love it!!.Classy Looking. Easy to install. Sim...  walmart    1  2017
# 11154  Love it!.Got this during Thanksgiving and was ...  walmart    1  2020
# 11155  Tried it out today, awesome results after use!...  walmart    1  2019
# 11156  Im a loyal Biobidet customer and I’m loving it...  walmart    1  2021
# ...                                                  ...      ...  ...   ...
# 12053  Oh what a relief it is!.I’ve had a skin condit...  walmart    1  2015
# 12054  Adaquate for the purpose.Would probably rate h...  walmart    1  2016
# 12055  Clean bum.I have been a plumbing contractor fo...  walmart    1  2016
# 12056  Good product.I installed BB-2000 to replace my...  walmart    1  2017
# 12057  Great product.I bought this product about two ...  walmart    1  2016
#
#            분기
# 11152  2017Q1
# 11153  2017Q1
# 11154  2020Q1
# 11155  2019Q1
# 11156  2021Q1
# ...       ...
# 12053  2015Q3
# 12054  2016Q3
# 12055  2016Q3
# 12056  2017Q3
# 12057  2016Q3
#
# [906 rows x 10 columns]

# %%
df91 = df9.groupby('분기').count().reset_index()[['분기', '리뷰수']]
df91['분기'] = df91['분기'].astype(str)
df91 = df91.loc[7:]
df91
# Out:
#         분기  리뷰수
# 7   2017Q1   66
# 8   2017Q2   51
# 9   2017Q3   33
# 10  2017Q4   21
# 11  2018Q1   15
# 12  2018Q2   11
# 13  2018Q3    7
# 14  2018Q4   21
# 15  2019Q1   31
# 16  2019Q2   15
# 17  2019Q3   11
# 18  2019Q4   25
# 19  2020Q1   41
# 20  2020Q2   75
# 21  2020Q3   66
# 22  2020Q4   46
# 23  2021Q1   47
# 24  2021Q2   37
# 25  2021Q3   26
# 26  2021Q4   23
# 27  2022Q1   35
# 28  2022Q2   24
# 29  2022Q3   21
# 30  2022Q4   10

# %% [markdown]
# #### 그래프

# %%
plt.figure(figsize=(10,6))  # 그래프 크기 설정
# 선 그래프 그리기
# sns.lineplot(data=df1, x='분기', y='리뷰수', marker='o')
plt.plot(df91['분기'], df91['리뷰수'], color='cyan', linestyle='-', linewidth=2.5, marker='p',  markerfacecolor='blue', markeredgecolor='blue', markersize=9.3)
plt.title('월마트_분기별 판매량 추이')  # 그래프 제목 설정
plt.xlabel('연도')  # x축 레이블 설정
plt.ylabel('리뷰수')  # y축 레이블 설정
plt.xticks(rotation=45)  # x축 눈금 레이블 회전 (필요한 경우)
plt.show()  # 그래프 출력

# %%
df92 = df9.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
df92['연도'] = df92['연도'].astype(str)
df92 = df92.loc[2:]
df92
# Out:
#       연도       회사명  리뷰수
# 2   2017  biobidet  157
# 3   2017  brondell   14
# 4   2018  biobidet   48
# 5   2018  brondell    6
# 6   2019  biobidet   77
# 7   2019  brondell    5
# 8   2020  biobidet  188
# 9   2020  brondell   40
# 10  2021  biobidet  107
# 11  2021  brondell   26
# 12  2022  biobidet   81
# 13  2022  brondell    9

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([colors[x] for x in df92['회사명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=df92, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('월마트_연도별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 브랜드별 리뷰개수

# %%
print('alphabidet : ', combined_review[combined_review['회사명']=='alphabidet']['제목_본문'].count())
print('a_s : ',combined_review[combined_review['회사명']=='a_s']['제목_본문'].count())
print('bidetmate : ',combined_review[combined_review['회사명']=='bidetmate']['제목_본문'].count())
print('biobidet : ',combined_review[combined_review['회사명']=='biobidet']['제목_본문'].count())
print('brondell : ',combined_review[combined_review['회사명']=='brondell']['제목_본문'].count())
print('kohler : ',combined_review[combined_review['회사명']=='kohler']['제목_본문'].count())
print('ovedecors : ',combined_review[combined_review['회사명']=='ovedecors']['제목_본문'].count())
print('toto : ',combined_review[combined_review['회사명']=='toto']['제목_본문'].count())
print('tushy : ',combined_review[combined_review['회사명']=='tushy']['제목_본문'].count())
print('vovo : ',combined_review[combined_review['회사명']=='vovo']['제목_본문'].count())
# Out:
# alphabidet :  426
# a_s :  170
# bidetmate :  242
# biobidet :  18386
# brondell :  7052
# kohler :  353
# ovedecors :  445
# toto :  1535
# tushy :  1845
# vovo :  101

# %%
br = combined_review.groupby(['연도', '회사명']).count().reset_index()[['연도', '회사명', '리뷰수']]
br = br[br['연도'].astype(str).astype(int)>=2017]
br
# Out:
#       연도         회사명   리뷰수
# 23  2017         a_s    81
# 24  2017  alphabidet    35
# 25  2017    biobidet   949
# 26  2017    brondell   547
# 27  2017      kohler    17
# 28  2017        toto    14
# 29  2018         a_s     6
# 30  2018  alphabidet    38
# 31  2018    biobidet  2630
# 32  2018    brondell  1037
# 33  2018      kohler    18
# 34  2018        toto    55
# 35  2018       tushy   104
# 36  2019         a_s    56
# 37  2019  alphabidet    33
# 38  2019    biobidet  3204
# 39  2019    brondell  1079
# 40  2019      kohler     4
# 41  2019   ovedecors    80
# 42  2019        toto   165
# 43  2019       tushy   254
# 44  2020         a_s    19
# 45  2020  alphabidet    58
# 46  2020   bidetmate    40
# 47  2020    biobidet  5798
# 48  2020    brondell  2351
# 49  2020      kohler    57
# 50  2020   ovedecors   187
# 51  2020        toto   236
# 52  2020       tushy   420
# 53  2021         a_s     2
# 54  2021  alphabidet    98
# 55  2021   bidetmate   115
# 56  2021    biobidet  1998
# 57  2021    brondell   891
# 58  2021      kohler    80
# 59  2021   ovedecors   102
# 60  2021        toto   512
# 61  2021       tushy   445
# 62  2021        vovo    73
# 63  2022         a_s     6
# 64  2022  alphabidet   145
# 65  2022   bidetmate    87
# 66  2022    biobidet  2128
# 67  2022    brondell   997
# 68  2022      kohler   173
# 69  2022   ovedecors    76
# 70  2022        toto   520
# 71  2022       tushy   622
# 72  2022        vovo    28

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='연도', y='리뷰수', hue='회사명', data=br, palette='Set2', dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('브랜드별 판매량 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### alphabidet

# %%
br1 = combined_review[combined_review['회사명']=='alphabidet']
br1 = br1.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br1 = br1[br1['연도'].astype(str).astype(int)>=2017]
br1
# Out:
#       연도     채널명  리뷰수
# 2   2017  amazon   35
# 3   2018  amazon   23
# 4   2018      hd   15
# 5   2019  amazon   25
# 6   2019      hd    8
# 7   2020  amazon   47
# 8   2020      hd   11
# 9   2021  amazon   92
# 10  2021      hd    6
# 11  2022  amazon  138
# 12  2022      hd    7

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br1['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br1, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('Alpha Bidet_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### american standard

# %%
br2 = combined_review[combined_review['회사명']=='a_s']
br2 = br2.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br2 = br2[br2['연도'].astype(str).astype(int)>=2017]
br2
# Out:
#       연도        채널명  리뷰수
# 0   2017  build.com   40
# 1   2017      lowes   41
# 2   2018  build.com    3
# 3   2018      lowes    3
# 4   2019  build.com   53
# 5   2019      lowes    3
# 6   2020  build.com   17
# 7   2020      lowes    2
# 8   2021  build.com    2
# 9   2022  build.com    5
# 10  2022      lowes    1

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br2['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br2, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('American Standard_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### bidetmate

# %%
br3 = combined_review[combined_review['회사명']=='bidetmate']
br3 = br3.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br3 = br3[br3['연도'].astype(str).astype(int)>=2017]
br3
# Out:
#      연도     채널명  리뷰수
# 0  2020  amazon   40
# 1  2021  amazon  115
# 2  2022  amazon   87

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br3['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br3, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('Bidet Mate_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### biobidet

# %%
br4 = combined_review[combined_review['회사명']=='biobidet']
br4 = br4.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br4 = br4[br4['연도'].astype(str).astype(int)>=2017]
br4
# Out:
#       연도        채널명   리뷰수
# 24  2017     amazon   160
# 25  2017  build.com   183
# 26  2017     costco   346
# 27  2017         hd    37
# 28  2017      lowes    66
# 29  2017    walmart   157
# 30  2018     amazon   324
# 31  2018  build.com    54
# 32  2018     costco  2127
# 33  2018         hd    58
# 34  2018      lowes    19
# 35  2018    walmart    48
# 36  2019     amazon   477
# 37  2019  build.com    72
# 38  2019     costco  2539
# 39  2019         hd    19
# 40  2019      lowes    20
# 41  2019    walmart    77
# 42  2020     amazon   801
# 43  2020  build.com   191
# 44  2020     costco  4547
# 45  2020         hd    30
# 46  2020      lowes    41
# 47  2020    walmart   188
# 48  2021     amazon   622
# 49  2021  build.com   119
# 50  2021     costco  1096
# 51  2021         hd    21
# 52  2021      lowes    33
# 53  2021    walmart   107
# 54  2022     amazon   264
# 55  2022  build.com    66
# 56  2022     costco  1686
# 57  2022         hd     9
# 58  2022      lowes    22
# 59  2022    walmart    81

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br4['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br4, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('Bio Bidet_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### brondell

# %%
br5 = combined_review[combined_review['회사명']=='brondell']
br5 = br5.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br5 = br5[br5['연도'].astype(str).astype(int)>=2017]
br5
# Out:
#       연도        채널명   리뷰수
# 11  2017     amazon    47
# 12  2017  build.com    34
# 13  2017     costco   360
# 14  2017         hd    23
# 15  2017      lowes    69
# 16  2017    walmart    14
# 17  2018     amazon   160
# 18  2018  build.com    20
# 19  2018     costco   746
# 20  2018         hd    47
# 21  2018      lowes    58
# 22  2018    walmart     6
# 23  2019     amazon   176
# 24  2019  build.com    19
# 25  2019     costco   717
# 26  2019         hd   121
# 27  2019      lowes    41
# 28  2019    walmart     5
# 29  2020     amazon   268
# 30  2020  build.com   112
# 31  2020     costco  1589
# 32  2020         hd   162
# 33  2020      lowes   180
# 34  2020    walmart    40
# 35  2021     amazon   359
# 36  2021  build.com    67
# 37  2021     costco   273
# 38  2021         hd    73
# 39  2021      lowes    93
# 40  2021    walmart    26
# 41  2022     amazon   215
# 42  2022  build.com    16
# 43  2022     costco   681
# 44  2022         hd    47
# 45  2022      lowes    29
# 46  2022    walmart     9

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br5['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br5, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('Brondell_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### kohler

# %%
br6 = combined_review[combined_review['회사명']=='kohler']
br6 = br6.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br6 = br6[br6['연도'].astype(str).astype(int)>=2017]
br6
# Out:
#       연도        채널명  리뷰수
# 2   2017  build.com   17
# 3   2018  build.com   18
# 4   2019  build.com    4
# 5   2020  build.com   39
# 6   2020      lowes   18
# 7   2021  build.com   53
# 8   2021     costco   12
# 9   2021      lowes   15
# 10  2022  build.com   56
# 11  2022     costco   98
# 12  2022      lowes   19

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br6['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br6, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('Kohler_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### ovedecors

# %%
br7 = combined_review[combined_review['회사명']=='ovedecors']
br7 = br7.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br7 = br7[br7['연도'].astype(str).astype(int)>=2017]
br7
# Out:
#      연도     채널명  리뷰수
# 0  2019  costco   80
# 1  2020  costco  187
# 2  2021  costco  102
# 3  2022  costco   76

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br7['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br7, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('OveDecors_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### toto

# %%
br8 = combined_review[combined_review['회사명']=='toto']
br8 = br8.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br8 = br8[br8['연도'].astype(str).astype(int)>=2017]
br8
# Out:
#       연도        채널명  리뷰수
# 4   2017     amazon   14
# 5   2018     amazon   55
# 6   2019     amazon  163
# 7   2019         hd    2
# 8   2020     amazon  221
# 9   2020  build.com    6
# 10  2020         hd    9
# 11  2021     amazon  448
# 12  2021  build.com   16
# 13  2021         hd   48
# 14  2022     amazon  433
# 15  2022  build.com   40
# 16  2022         hd   47

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br8['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br8, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('TOTO_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### tushy

# %%
br9 = combined_review[combined_review['회사명']=='tushy']
br9 = br9.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br9 = br9[br9['연도'].astype(str).astype(int)>=2017]
br9
# Out:
#      연도     채널명  리뷰수
# 0  2018  amazon  104
# 1  2019  amazon  254
# 2  2020  amazon  420
# 3  2021  amazon  445
# 4  2022  amazon  622

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br9['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br9, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('Tushy_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### vovo

# %%
br10 = combined_review[combined_review['회사명']=='vovo']
br10 = br10.groupby(['연도', '채널명']).count().reset_index()[['연도', '채널명', '리뷰수']]
br10 = br10[br10['연도'].astype(str).astype(int)>=2017]
br10
# Out:
#      연도    채널명  리뷰수
# 0  2021  lowes   73
# 1  2022  lowes   28

# %% [markdown]
# #### 막대그래프

# %%
plt.figure(figsize=(10, 6))
palette = sns.color_palette([channel[x] for x in br10['채널명'].unique()])
sns.barplot(x='연도', y='리뷰수', hue='채널명', data=br10, palette=palette, dodge=False)

plt.xlabel('연도')
plt.ylabel('리뷰수')
plt.title('VOVO_브랜드 점유율 추이')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 제품별 리뷰개수

# %%
combined_review
# Out:
#              회사명  고유 제품명 형태        작성일  별점  \
# 0       biobidet   BB A8  E 2016-12-01   5
# 1       biobidet   BB A8  E 2016-11-06   5
# 2       biobidet   BB A8  E 2019-09-17   5
# 3       biobidet   BB A8  E 2020-10-02   4
# 4       biobidet   BB A8  E 2019-05-13   5
# ...          ...     ... ..        ...  ..
# 30550  ovedecors  Irenne  E 2022-02-03   5
# 30551  ovedecors  Irenne  E 2022-06-03   5
# 30552  ovedecors  Irenne  E 2022-06-03   4
# 30553  ovedecors  Irenne  E 2020-11-30   5
# 30554  ovedecors  Irenne  E 2021-11-30   5
#
#                                                    제목_본문     채널명  리뷰수    연도  \
# 0      AMAZING.I couldn’t be happier!!! A must for an...   lowes    1  2016
# 1      Good Product!.It takes just minutes to install...   lowes    1  2016
# 2      Very Satisfied....Love the night glow light. V...   lowes    1  2019
# 3      Great features and easy to install.Steady hot ...   lowes    1  2020
# 4      Wonderful features.I bought 10 days ago and us...   lowes    1  2019
# ...                                                  ...     ...  ...   ...
# 30550  Worth every penny.We love our new toilet! We h...  costco    1  2022
# 30551  Worth every penny!.It’s a beautiful toilet tha...  costco    1  2022
# 30552  Worth it.I’ve had this for a couple weeks now ...  costco    1  2022
# 30553  You will miss this.Good but needs some tweakin...  costco    1  2020
# 30554  You’re mad if you didn’t buy this... :).Easy i...  costco    1  2021
#
#            분기
# 0      2016Q4
# 1      2016Q4
# 2      2019Q3
# 3      2020Q4
# 4      2019Q2
# ...       ...
# 30550  2022Q1
# 30551  2022Q2
# 30552  2022Q2
# 30553  2020Q4
# 30554  2021Q4
#
# [30555 rows x 10 columns]

# %% [markdown]
# # 시계열 리뷰 긍정/부정 추이

# %%
# 데이터프레임 정렬 (필요한 경우)
combined_review.sort_values(by='작성일')
# Out:
#               회사명       고유 제품명 형태        작성일  별점  \
# 11151    biobidet        BB600  E 2009-04-12   5
# 11150    biobidet        BB600  E 2009-07-28   2
# 11149    biobidet        BB600  E 2010-01-11   5
# 11148    biobidet        BB600  E 2010-01-17   5
# 11147    biobidet        BB600  E 2010-03-30   3
# ...           ...          ... ..        ...  ..
# 2542   alphabidet     Alpha JX  R 2022-12-06   5
# 2541        tushy    Basic 2.0  A 2022-12-06   5
# 2540        tushy    Basic 2.0  A 2022-12-06   5
# 2544        tushy  Classic 3.0  A 2022-12-06   3
# 2047       kohler       C3-155  E 2022-12-06   1
#
#                                                    제목_본문        채널명  리뷰수  \
# 11151  BB-1000 is the BEST!.Once you use one of these...     amazon    1
# 11150  Not very durable.We bought ours in 2006, it on...     amazon    1
# 11149  Bio Bidet Supreme BB 1000 Bidet.The Bio Bidet ...     amazon    1
# 11148  Nice features for the money..I am very pleased...     amazon    1
# 11147  Love that warm seat, but a buyer should know.....     amazon    1
# ...                                                  ...        ...  ...
# 2542   The whole family loves the bidet..I don’t know...     amazon    1
# 2541   Cleanliness.My husband loves this contraption!...     amazon    1
# 2540       Pour le grande toilette et pas sentir le cul.     amazon    1
# 2544   Not for women.I read the questions on this ite...     amazon    1
# 2047      Would have been good if it would have fit ....  build.com    1
#
#          연도      분기
# 11151  2009  2009Q2
# 11150  2009  2009Q3
# 11149  2010  2010Q1
# 11148  2010  2010Q1
# 11147  2010  2010Q1
# ...     ...     ...
# 2542   2022  2022Q4
# 2541   2022  2022Q4
# 2540   2022  2022Q4
# 2544   2022  2022Q4
# 2047   2022  2022Q4
#
# [30555 rows x 10 columns]

# %% [markdown]
# # 파일 저장

# %%
# train_random.to_excel('bidet_train_data.xlsx', index=False)

# %%
# test_random.to_excel('bidet_test_data.xlsx', index=False)
